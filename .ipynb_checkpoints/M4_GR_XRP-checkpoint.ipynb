# %% [markdown]
# # GammaRegressor

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('XRP.csv')
del data['Date']
del data['Adj Close']
data.head()
# Out:
#        High       Low      Open     Close   Volume
# 0  0.005803  0.005123  0.005123  0.005399  1281960
# 1  0.005521  0.005091  0.005398  0.005135   491147
# 2  0.005167  0.004873  0.005134  0.004942   407109
# 3  0.004954  0.004736  0.004942  0.004772   322621
# 4  0.004791  0.004540  0.004768  0.004570   309571

# %%
data.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume'], dtype='object')

# %%
data.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume'], dtype='object')

# %%
data.isnull()
# Out:
#       High    Low   Open  Close  Volume
# 0    False  False  False  False   False
# 1    False  False  False  False   False
# 2    False  False  False  False   False
# 3    False  False  False  False   False
# 4    False  False  False  False   False
# ..     ...    ...    ...    ...     ...
# 832  False  False  False  False   False
# 833  False  False  False  False   False
# 834  False  False  False  False   False
# 835  False  False  False  False   False
# 836  False  False  False  False   False
#
# [837 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# High      0
# Low       0
# Open      0
# Close     0
# Volume    0
# dtype: int64

# %%
df=data.dropna()

# %%
df.head()
# Out:
#        High       Low      Open     Close   Volume
# 0  0.005803  0.005123  0.005123  0.005399  1281960
# 1  0.005521  0.005091  0.005398  0.005135   491147
# 2  0.005167  0.004873  0.005134  0.004942   407109
# 3  0.004954  0.004736  0.004942  0.004772   322621
# 4  0.004791  0.004540  0.004768  0.004570   309571

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 832    False
# 833    False
# 834    False
# 835    False
# 836    False
# Length: 837, dtype: bool

# %%
sum(df.duplicated())
# Out:
# 0

# %%
x = df.drop(labels='Close',axis=1)
y = df.loc[:,'Close']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
print("NUMBER OF TRAIN DATASET:",len(x_train))
print("NUMBER OF TEST DATASET:",len(x_test))
print("TOTAL NUMBER OF DATASET :",len(x_train)+len(x_test))
# Out:
# NUMBER OF TRAIN DATASET: 669
# NUMBER OF TEST DATASET: 168
# TOTAL NUMBER OF DATASET : 837

# %%
from sklearn.linear_model import ElasticNet
GR=ElasticNet()
GR.fit(x_train,y_train)
predicted=GR.predict(x_test)

# %%
from sklearn.metrics import r2_score
R2 = r2_score(y_test,predicted)
print("THE R2 SCORE OF ElasticNet IS :",R2)
# Out:
# THE R2 SCORE OF ElasticNet IS : 0.0725494586609573

# %%
from sklearn.metrics import rand_score
RAND = rand_score(y_test,predicted)
print("THE ACCURACY SCORE OF ElasticNet IS :",RAND*100)
# Out:
# THE ACCURACY SCORE OF ElasticNet IS : 100.0

# %%
from sklearn.metrics import explained_variance_score
EVS = explained_variance_score(y_test,predicted)
print("THE EXPLAINED VARIENCE SCORE OF ElasticNet IS :",EVS)
# Out:
# THE EXPLAINED VARIENCE SCORE OF ElasticNet IS : 0.07758570328460168

# %%
from sklearn.metrics import mean_squared_error
MSE = mean_squared_error(y_test,predicted)
print("THE MEAN SQUARED ERROR SCORE OF ElasticNet IS :",MSE)
# Out:
# THE MEAN SQUARED ERROR SCORE OF ElasticNet IS : 1.1756226597034892e-05

# %%
from sklearn.metrics import median_absolute_error
MAE = median_absolute_error(y_test,predicted)
print("THE MEAN ABSOLUTE ERROR SCORE OF ElasticNet IS :",MAE)
# Out:
# THE MEAN ABSOLUTE ERROR SCORE OF ElasticNet IS : 0.0017289801347908753

# %%
df2=pd.DataFrame()
df2["y_test"]=y_test
df2["predicted"]=predicted
df2.reset_index(inplace=True)
plt.figure(figsize=(20,5))
plt.plot(df2["predicted"][:100], marker='x', linestyle='dashed', color='red')
plt.plot(df2["y_test"][:100],  marker='o', linestyle='dashed', color='green')
plt.show()

# %%
import joblib
joblib.dump(GR, 'XRP.pkl')
# Out:
# ['XRP.pkl']
